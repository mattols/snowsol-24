# %% [markdown]
# ### Create skyview factor

# %%
from osgeo import gdal, osr
from topocalc.viewf import viewf
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in DEM
# d = "/uufs/chpc.utah.edu/common/home/skiles-group1/jmeyer/project-data/iSnobal/ERW/topo/basin_setup/topo.nc"
# d = "/uufs/chpc.utah.edu/common/home/u1037042/Documents/isnobal_data/toponc_ERW/topo.nc"
d = '/uufs/chpc.utah.edu/common/home/skiles-group2/pnaple/DRFS-Fusion/fusion_files/DEM/034033_merged.tif'
topo = gdal.Open(d, gdal.GA_ReadOnly)
topo.RasterCount
# Out:
# 1

# %%
# convert elevation to type for tpocalc
dem = topo.GetRasterBand(1).ReadAsArray()
dem = dem.astype(np.double)
dem
# Out:
# array([[1895., 1895., 1894., ..., 1475., 1476., 1476.],
#        [1895., 1895., 1894., ..., 1474., 1475., 1475.],
#        [1895., 1895., 1895., ..., 1473., 1474., 1474.],
#        ...,
#        [2648., 2645., 2639., ..., 1737., 1738., 1739.],
#        [2641., 2638., 2635., ..., 1737., 1738., 1739.],
#        [2633., 2631., 2629., ..., 1737., 1738., 1739.]])

# %%
# plot DEM
# Read the data from the first band
band = topo.GetRasterBand(1)
data = band.ReadAsArray()

# Get the geotransform information
geotransform = topo.GetGeoTransform()

# Plot the data
plt.imshow(data, cmap='gray', extent=[geotransform[0], geotransform[0] + geotransform[1] * topo.RasterXSize,
                                      geotransform[3] + geotransform[5] * topo.RasterYSize, geotransform[3]])
plt.colorbar()
plt.show()

# %%
# generate sky view factor !!!
geotransform = topo.GetGeoTransform()
x_resolution = geotransform[1]

sv = viewf(
    # "/uufs/chpc.utah.edu/common/home/u1037042/Documents/isnobal_data/toponc_ERW/topo.nc",
    dem,
    float(x_resolution)
)
sv
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 5
#       2 geotransform = topo.GetGeoTransform()
#       3 x_resolution = geotransform[1]
# ----> 5 sv = viewf(
#       6     # "/uufs/chpc.utah.edu/common/home/u1037042/Documents/isnobal_data/toponc_ERW/topo.nc",
#       7     dem,
#       8     float(x_resolution)
#       9 )
#      10 sv
#
# File ~/software/pkg/miniconda3/envs/smeshr/lib/python3.10/site-packages/topocalc/viewf.py:85, in viewf(dem, spacing, nangles, sin_slope, aspect)
#      81 svf = np.zeros_like(sin_slope)
#      82 for angle in angles:
#      83
#      84     # horizon angles
# ---> 85     hcos = horizon(angle, dem, spacing)
#      86     azimuth = d2r(angle)
#      88     # sin^2(H)
#
# File ~/software/pkg/miniconda3/envs/smeshr/lib/python3.10/site-packages/topocalc/horizon.py:100, in horizon(azimuth, dem, spacing)
#      98     a = azimuth + 180
#      99     t, spacing = skew_transpose(dem, spacing, a)
# --> 100     h = hor2d_c(t, spacing, fwd=False)
#     101     hcos = skew(h.transpose(), a, fwd=False)
#     103 elif azimuth >= 135 and azimuth < 180:
#     104     # North East
#
# File ~/software/pkg/miniconda3/envs/smeshr/lib/python3.10/site-packages/topocalc/horizon.py:163, in hor2d_c(z, spacing, fwd)
#     159 z = np.ascontiguousarray(z)
#     161 h = np.zeros_like(z)
# --> 163 topo_core.c_hor2d(z, spacing, fwd, h)
#     165 # if not fwd:
#     166 #     h = np.fliplr(h)
#     168 return h
#
# KeyboardInterrupt:

# %%
# plot sky view factor
geotransform = topo.GetGeoTransform()

# Plot the data
plt.imshow(sv[0], cmap='gray', extent=[geotransform[0], geotransform[0] + geotransform[1] * topo1.RasterXSize,
                                      geotransform[3] + geotransform[5] * topo1.RasterYSize, geotransform[3]])
plt.colorbar()
plt.show()

# %%
arr_out = sv[0]
outFileName = '/uufs/chpc.utah.edu/common/home/uvu-group1/olson/'

driver = gdal.GetDriverByName("GTiff")
outdata = driver.Create(outFileName, cols, rows, 1, gdal.GDT_UInt16)
outdata.SetGeoTransform(ds.GetGeoTransform())##sets same geotransform as input
outdata.SetProjection(ds.GetProjection())##sets same projection as input
outdata.GetRasterBand(1).WriteArray(arr_out)
outdata.GetRasterBand(1).SetNoDataValue(10000)##if you want these values transparent
outdata.FlushCache() ##saves to disk!!
outdata = None
band=None
ds=None
