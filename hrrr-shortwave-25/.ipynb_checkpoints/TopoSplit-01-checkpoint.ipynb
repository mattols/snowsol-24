# %% [markdown]
# ## TopoSplit Models
#
# Generate forcing data using 4 separate models

# %%
# libraries
import numpy as np
from datetime import datetime, timedelta
import math as m

from netCDF4 import Dataset

from snobedo.input import HrrrParameter, SmrfTopo
from snobedo.shortwave import TopoShade
from snobedo.input import SmrfTopo

import matplotlib.pyplot as plt

from topocalc.horizon import horizon
from topocalc.shade import shade

# cusotm functions
import topo_split as tsw

# %%
# custom functions

# %%
# paths
UVU_OLSON_HOME = '/uufs/chpc.utah.edu/common/home/uvu-group1/olson/snow-data/'
HRRR_DATA = UVU_OLSON_HOME + 'HRRR_2022/'
ERW_TOPO_FILE = UVU_OLSON_HOME + 'isnobal-data/ERW_topo.nc'

# %% [markdown]
# ### HRRR file (single)

# %%
# Set the PROJ_LIB environment variable
# Annoying Jupter bug
import os
os.environ['PROJ_LIB'] = '/uufs/chpc.utah.edu/common/home/skiles-group1/jmeyer/conda/envs/smeshr/share/proj' 
hrrr_dswrf = HrrrParameter(ERW_TOPO_FILE, HRRR_DATA + 'hrrr.20220301/hrrr.t09z.wrfsfcf06.grib2', 'cubic')

# %% [markdown]
# ### For single moment

# %%
# load terrain variables
dem, sky_view_factor, topo_shade = tsw.static_topo_vars(ERW_TOPO_FILE)

# calculate solar geometry (FUll day)
azimuth, zenith, incidence_angles, illumination = tsw.hrrr_solar_geom(hrrr_dswrf, topo_shade)

# run models
ghi, dsw1, dsw2, dsw3 = tsw.toposplitModels4(hrrr_dswrf, zenith, azimuth, incidence_angles, illumination, sky_view_factor, topo_shade)

# plot
dsw3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       2 dem, sky_view_factor, topo_shade = tsw.static_topo_vars(ERW_TOPO_FILE)
#       4 # calculate solar geometry (FUll day)
# ----> 5 azimuth, zenith, incidence_angles, illumination = tsw.hrrr_solar_geom(hrrr_dswrf, topo_shade)
#       7 # run models
#       8 ghi, dsw1, dsw2, dsw3 = tsw.toposplitModels4(hrrr_dswrf, zenith, azimuth, incidence_angles, illumination, sky_view_factor, topo_shade)
#
# File ~/Documents/src/snowtools/snowsol-24/hrrr-shortwave-25/topo_split.py:48, in hrrr_solar_geom(hrrr_dswrf, topo_shade)
#      45 incidence = { key.strftime('%Y-%m-%d %H:%M'): value for key, value in topo_shade.illumination_angles.items() }
#      47 # shading corrected incidence
# ---> 48 illumination = horizon_shader(topo_shade, zenith, incidence) # full day - includes shading
#      50 return azimuth, zenith, incidence, illumination
#
# File ~/Documents/src/snowtools/snowsol-24/hrrr-shortwave-25/topo_split.py:72, in horizon_shader(topo_shade, zenith, illumination_angles)
#      70     if type(illumination_angles[date]) is np.ndarray:
#      71         inc_copy[date] = mask_sun(date, zenith, illumination_angles, horizon_angles)
# ---> 72 inc = { key.strftime('%Y-%m-%d %H:%M'): value for key, value in inc_copy.items() }
#      73 return inc
#
# File ~/Documents/src/snowtools/snowsol-24/hrrr-shortwave-25/topo_split.py:72, in <dictcomp>(.0)
#      70     if type(illumination_angles[date]) is np.ndarray:
#      71         inc_copy[date] = mask_sun(date, zenith, illumination_angles, horizon_angles)
# ---> 72 inc = { key.strftime('%Y-%m-%d %H:%M'): value for key, value in inc_copy.items() }
#      73 return inc
#
# AttributeError: 'str' object has no attribute 'strftime'

# %%
# PLOT MODELS
fig, ax = plt.subplots(ncols=2, nrows=3, dpi=200, figsize=(6,8), sharex=True, sharey=True)
ax = ax.flatten()

axes_args = dict(cmap='plasma', vmax=(ghi.max() + 100), vmin=0)
title_args = dict(fontsize=10)

# Plot and create colorbars
im0 = ax[0].imshow(ghi, **axes_args)
ax[0].set_title('dswrf', **title_args)
fig.colorbar(im0, ax=ax[0], label="W/m²")

im1 = ax[1].imshow(dsw1, **axes_args)
ax[1].set_title('dsw1', **title_args)
fig.colorbar(im1, ax=ax[1], label="W/m²")

im2 = ax[2].imshow(dsw2, **axes_args)
ax[2].set_title('dsw2', **title_args)
fig.colorbar(im2, ax=ax[2], label="W/m²")

im3 = ax[3].imshow(dsw3, **axes_args)
ax[3].set_title('dsw3', **title_args)
fig.colorbar(im3, ax=ax[3], label="W/m²")

im4 = ax[4].imshow(dsw2 - ghi, cmap='RdBu', vmin=-400, vmax=400)
ax[4].set_title('dsw2 - ghi')
fig.colorbar(im4, ax=ax[4], label="W/m²")

im5 = ax[5].imshow(dsw3 - dsw1, cmap='RdBu', vmin=-100, vmax=100)
ax[5].set_title('dsw3 - dsw1')
fig.colorbar(im5, ax=ax[5], label="W/m²")

plt.tight_layout()
plt.show()

# %%
# issue with handling days that cross over to next HRRR grib?
# i.e. make sure that HRRR date matches with zenith etc.
